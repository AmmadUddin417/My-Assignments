# %% [markdown]
# # 1. Variables + print()
#  1.	Student Information — Store name, age, course, and institute in variables. Display them using print().

# %%
name = "Ammad"
age = 18
course = "AI and Data Science"
institute = "Saylani Mass IT Program "
print (f"""
Name : {name}
Age : {age}
course : {course}
institute : {institute}
""" )
# Out:
# Name : Ammad
# Age : 18
# course : AI and Data Science
# institute : Saylani Mass IT Program

# %% [markdown]
# 2.Employee Information — Store employee name, department, salary, and experience. Print a simple employee profile.

# %%
Emp_name = "Ammad"
Emp_Dep = "Data Science"
Emp_Salary = 100000
Emp_exp = "No Experience"
print (f"""
Employee name : {Emp_name}
Employee Department : {Emp_Dep}
Employee Salary : {Emp_Salary}
Employee Experience : {Emp_exp}
""")
# Out:
# Employee name : Ammad
# Employee Department : Data Science
# Employee Salary : 100000
# Employee Experience : No Experience

# %% [markdown]
# 3.	Product Information — Store product name, price, and quantity. Display all information.

# %%
prod_name = "Laptop"
prod_price = 450000
prod_quantity = 3
print (f"""
Product Name = {prod_name}
Product Price = {prod_price}
Product Quantity = {prod_quantity}
""")
# Out:
# Product Name = Laptop
# Product Price = 450000
# Product Quantity = 3

# %% [markdown]
# ## 2. input() Function
# 1.	Personal Introduction — Ask the user for name, age, city, and course. Print a sentence introducing the student.

# %%
name = input("Enter your name :")
age = int(input("Enter your age :"))
city = input(
